# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import requests, json
pd.set_option('display.float_format', '{:.2f}'.format)
pd.set_option('display.max_columns', None)

# %%
df_bicycle = pd.read_csv('Bicycle_Thefts_Open_Data.csv')
df = df_bicycle.copy()
df.head()
# Out:
#             X          Y  OBJECTID EVENT_UNIQUE_ID   PRIMARY_OFFENCE  \
# 0 -8838282.52 5409902.51         1  GO-20141263544               B&E
# 1 -8843626.12 5409538.96         2  GO-20141261431       THEFT UNDER
# 2 -8840398.79 5413057.03         3  GO-20141263784  PROPERTY - FOUND
# 3 -8838072.94 5410325.76         4  GO-20149000090       THEFT UNDER
# 4 -8835727.45 5411803.31         5  GO-20149000074       THEFT UNDER
#
#                  OCC_DATE  OCC_YEAR OCC_MONTH    OCC_DOW  OCC_DAY  OCC_DOY  \
# 0  2013/12/26 05:00:00+00      2013  December   Thursday       26      360
# 1  2014/01/01 05:00:00+00      2014   January  Wednesday        1        1
# 2  2014/01/01 05:00:00+00      2014   January  Wednesday        1        1
# 3  2014/01/01 05:00:00+00      2014   January  Wednesday        1        1
# 4  2013/12/25 05:00:00+00      2013  December  Wednesday       25      359
#
#    OCC_HOUR             REPORT_DATE  REPORT_YEAR REPORT_MONTH REPORT_DOW  \
# 0        19  2014/01/01 05:00:00+00         2014      January  Wednesday
# 1         7  2014/01/01 05:00:00+00         2014      January  Wednesday
# 2        18  2014/01/01 05:00:00+00         2014      January  Wednesday
# 3        12  2014/01/02 05:00:00+00         2014      January   Thursday
# 4        16  2014/01/02 05:00:00+00         2014      January   Thursday
#
#    REPORT_DAY  REPORT_DOY  REPORT_HOUR DIVISION  \
# 0           1           1           17      D14
# 1           1           1            7      D14
# 2           1           1           18      D14
# 3           2           2           20      D52
# 4           2           2           16      D51
#
#                                        LOCATION_TYPE PREMISES_TYPE  \
# 0  Other Commercial / Corporate Places (For Profi...    Commercial
# 1                   Apartment (Rooming House, Condo)     Apartment
# 2  Single Home, House (Attach Garage, Cottage, Mo...         House
# 3                   Apartment (Rooming House, Condo)     Apartment
# 4                   Apartment (Rooming House, Condo)     Apartment
#
#     BIKE_MAKE   BIKE_MODEL BIKE_TYPE  BIKE_SPEED BIKE_COLOUR  BIKE_COST  \
# 0        FELT          F59        RC       21.00      SILRED    1300.00
# 1  SUPERCYCLE          NaN        MT       10.00         NaN        NaN
# 2        TREK       SOHO S        RG        1.00         BLK        NaN
# 3          GI  TCX2 (2010)        OT        9.00         BLU    1019.00
# 4          CA     RZ 120 1        MT       21.00         WHI    1500.00
#
#       STATUS HOOD_158        NEIGHBOURHOOD_158 HOOD_140  \
# 0     STOLEN      165   Harbourfront-CityPlace       77
# 1     STOLEN       85           South Parkdale       85
# 2  RECOVERED       80  Palmerston-Little Italy       80
# 3     STOLEN      165   Harbourfront-CityPlace       77
# 4     STOLEN      168      Downtown Yonge East       75
#
#                         NEIGHBOURHOOD_140  LONG_WGS84  LAT_WGS84
# 0  Waterfront Communities-The Island (77)      -79.40      43.64
# 1                     South Parkdale (85)      -79.44      43.64
# 2            Palmerston-Little Italy (80)      -79.41      43.66
# 3  Waterfront Communities-The Island (77)      -79.39      43.64
# 4              Church-Yonge Corridor (75)      -79.37      43.65
